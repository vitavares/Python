# %% [markdown]
# ## Variáveis e tipos de dados

# %% [markdown]
# ### Tipos nativos
# - **Tipos numéricos:** `int` e `float`
# - **Tipos de texto:** `str`
# - **Tipos lógicos:** `bool`
# - **Tipo vazio:** `NoneType`

# %% [markdown]
# #### Exercicio do módulo
#
# **1**
# - Crie uma célula de código que escreva o texto "Olá mundo!", utilize o comando print .
# - Crie uma célua de texto e adicione uma imagem.
#
# **2**
# - Preencha as células de código para preencher os valores de (A), (B) e (C) na tabela de ticket
# médio abaixo:
#
# ![image.png](attachment:image.png)
#
# **3**
# - Aplique três métodos distintos na string abaixo:
#
# `cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'`
#
# - Extraia da string abaixo o valor da taxa selic na variável selic e o valor do ano na variavel
# ano . Imprima os valores na tela.
#
# `noticia = 'Selic vai a 2,75% e supera expectativas; ' + \
# 'é a primeira alta em 6 anos.'`
#
# **4**
# - Utilize a tabela da verdade para responder: qual o valor da variável x?
#
# `a = False
# b = True
# x = not a & b`

# %% [markdown]
# #### Respostas:

# %%
# 1
print('Olá, mundo!')
# Out:
# Olá, mundo!

# %% [markdown]
# Imagem:
#
# ![image.png](attachment:image.png)

# %%
# 2

valor_A = 320.52 / 3
valor_B = 834.47 / 119.21
valor_C = 15378.12 / 5

# %%
# 3
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'

print(cancao.capitalize())
print(cancao.upper())

noticia = "Selic vai a 2,75% e supera expectativas; ' + 'é a primeira alta em 6 anos."

palavras = noticia.split()
ind_selic = palavras.index('Selic')
ind_ano = palavras.index('anos.')
taxa_Selic = palavras[ind_selic + 3]
ano = palavras[ind_ano - 1]

print('Taxa selic: ', taxa_Selic)
print('Ano: ', ano)
# Out:
# Roda mundo, roda gigante, roda moinho, roda pião.
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.
# Taxa selic:  2,75%
# Ano:  6

# %% [markdown]
# - 4
#
# ![image.png](attachment:image.png)
